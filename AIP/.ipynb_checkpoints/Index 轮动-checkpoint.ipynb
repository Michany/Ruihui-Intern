# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  
import matplotlib as mpl

# %%
import pymssql
def get_findata(SQL,write_to_file = 'off'):
    
    conn=pymssql.connect(server='192.168.0.28', port=1433, user='sa', password='abc123', database='rawdata',charset = 'GBK')
    
    data = pd.read_sql(SQL,conn)
    
    if write_to_file == 'on':
        data.to_csv('data.csv')

    return data

# %%
PE = get_findata("select * from dbo.Zindexes_PE")

# %%
PE.dropna(thresh = 30).set_index('Date').plot(figsize=(20,10))

# %%
pe = PE.dropna(thresh = 30).set_index('Date')

# %%
# pe从日频改成周频
pe = pe.resample('1W').last()

# %%
# 直接用最低的pe来配置仓位不够合理，会导致仓位长期集中在某个指数
pe.rank(axis=1).iloc[[1,-1]].T
# Out:
# Date              2012-06-17  2018-08-12
# PE_TTM_WDQA             13.0        13.0
# PE_TTM_SZ50              7.0         6.0
# PE_TTM_SH               11.0        11.0
# PE_TTM_ZZ500            24.0        22.0
# PE_TTM_CYB              29.0        34.0
# PE_TTM_HS300            10.0         9.0
# PE_TTM_000925_SH         5.0         5.0
# PE_TTM_399001_SZ        15.0        17.0
# PE_TTM_399985_SZ        12.0        12.0
# PE_TTM_399005_SZ        20.0        24.0
# PE_TTM_000010_SH         8.0         8.0
# PE_TTM_000009_SH        19.0        15.0
# PE_TTM_000922_SH         6.0         2.0
# PE_TTM_399396_SZ         NaN        27.0
# PE_TTM_000991_SH        25.0        30.0
# PE_TTM_000978_SH        23.0        31.0
# PE_TTM_000827_SH         NaN        18.0
# PE_TTM_000998_SH        27.0        28.0
# PE_TTM_399550_SZ         3.0         4.0
# PE_TTM_399971_SZ         NaN        25.0
# PE_TTM_000964_SH        17.0        19.0
# PE_TTM_399812_SZ         NaN        20.0
# PE_TTM_000069_SH        16.0        21.0
# PE_TTM_000065_SH         9.0        10.0
# PE_TTM_884153_WI         NaN        23.0
# PE_TTM_000993_SH        28.0        33.0
# PE_TTM_000931_SH        14.0        14.0
# PE_TTM_000932_SH        21.0        26.0
# PE_TTM_000933_SH        22.0        29.0
# PE_TTM_000934_SH         2.0         1.0
# PE_TTM_000935_SH        26.0        32.0
# PE_TTM_399937_SZ        18.0        16.0
# PE_TTM_HSI_HI            4.0         7.0
# PE_TTM_HSCEI_HI          1.0         3.0

# %%
indexes = list(pe.columns)
# Out:
# ['PE_TTM_WDQA',
#  'PE_TTM_SZ50',
#  'PE_TTM_SH',
#  'PE_TTM_ZZ500',
#  'PE_TTM_CYB',
#  'PE_TTM_HS300',
#  'PE_TTM_000925_SH',
#  'PE_TTM_399001_SZ',
#  'PE_TTM_399985_SZ',
#  'PE_TTM_399005_SZ',
#  'PE_TTM_000010_SH',
#  'PE_TTM_000009_SH',
#  'PE_TTM_000922_SH',
#  'PE_TTM_399396_SZ',
#  'PE_TTM_000991_SH',
#  'PE_TTM_000978_SH',
#  'PE_TTM_000827_SH',
#  'PE_TTM_000998_SH',
#  'PE_TTM_399550_SZ',
#  'PE_TTM_399971_SZ',
#  'PE_TTM_000964_SH',
#  'PE_TTM_399812_SZ',
#  'PE_TTM_000069_SH',
#  'PE_TTM_000065_SH',
#  'PE_TTM_884153_WI',
#  'PE_TTM_000993_SH',
#  'PE_TTM_000931_SH',
#  'PE_TTM_000932_SH',
#  'PE_TTM_000933_SH',
#  'PE_TTM_000934_SH',
#  'PE_TTM_000935_SH',
#  'PE_TTM_399937_SZ',
#  'PE_TTM_HSI_HI',
#  'PE_TTM_HSCEI_HI']

# %% [markdown]
# ## 计算移动平均线,相对PE

# %%
rpe={}
for index in indexes: 
    #计算移动平均线
    #mean[index]=pe[index].rolling(5).mean()
    #计算相对PE
    temp=pe[index]/pe[index][0]
    rpe[index] = temp
rpe=pd.DataFrame(rpe)
'''for index in indexes: 
    rpe.loc[26:,index]=pe[index]/pe[index].shift(26)'''
# Out:
# 'for index in indexes: \n    rpe.loc[26:,index]=pe[index]/pe[index].shift(26)'

# %%
rpe.plot(figsize=(15,10))

# %% [markdown]
# ## 计算仓位

# %%
index_amount = 3
frequency = 3
rank=rpe.rank(axis=1)

# 调仓时间点
chg_time = pd.Series(np.arange(len(pe)) % frequency, index = pe.index)
chg_pos =  chg_time == 0

# %%
#赋权重(仓位)
pos=rpe.copy()
longer_pos = rpe.copy()
for index in indexes:
    pos[index] = rank[index].apply(lambda x: 1/index_amount if x<=index_amount else 0) 
    for i in range(len(pos.index)):
        if chg_pos.iloc[i]:
            longer_pos.loc[pos.index[i],index] = pos[index].iloc[i]
        else:
            longer_pos.loc[pos.index[i],index] = pos[index].iloc[i-chg_time.iloc[i]]
#设置止损
#如果该市场指数下跌跌破均线，则止损
'''for index in indexes:
    t.loc[(t['Close',index]<t['AveClose',index]) & (t['Close',index]<t['Close',index].shift(2)),
          ('w',index)] = 0'''
#如果市场指数上穿均线，则开仓
# Out:
# "for index in indexes:\n    t.loc[(t['Close',index]<t['AveClose',index]) & (t['Close',index]<t['Close',index].shift(2)),\n          ('w',index)] = 0"

# %%
pos.describe()
# Out:
#        PE_TTM_WDQA  PE_TTM_SZ50  PE_TTM_SH  PE_TTM_ZZ500  PE_TTM_CYB  \
# count        323.0        323.0      323.0    323.000000  323.000000
# mean           0.0          0.0        0.0      0.051600    0.021672
# std            0.0          0.0        0.0      0.120758    0.082312
# min            0.0          0.0        0.0      0.000000    0.000000
# 25%            0.0          0.0        0.0      0.000000    0.000000
# 50%            0.0          0.0        0.0      0.000000    0.000000
# 75%            0.0          0.0        0.0      0.000000    0.000000
# max            0.0          0.0        0.0      0.333333    0.333333
#
#        PE_TTM_HS300  PE_TTM_000925_SH  PE_TTM_399001_SZ  PE_TTM_399985_SZ  \
# count    323.000000        323.000000        323.000000             323.0
# mean       0.003096          0.036120          0.003096               0.0
# std        0.032025          0.103772          0.032025               0.0
# min        0.000000          0.000000          0.000000               0.0
# 25%        0.000000          0.000000          0.000000               0.0
# 50%        0.000000          0.000000          0.000000               0.0
# 75%        0.000000          0.000000          0.000000               0.0
# max        0.333333          0.333333          0.333333               0.0
#
#        PE_TTM_399005_SZ       ...         PE_TTM_884153_WI  PE_TTM_000993_SH  \
# count             323.0       ...                    323.0             323.0
# mean                0.0       ...                      0.0               0.0
# std                 0.0       ...                      0.0               0.0
# min                 0.0       ...                      0.0               0.0
# 25%                 0.0       ...                      0.0               0.0
# 50%                 0.0       ...                      0.0               0.0
# 75%                 0.0       ...                      0.0               0.0
# max                 0.0       ...                      0.0               0.0
#
#        PE_TTM_000931_SH  PE_TTM_000932_SH  PE_TTM_000933_SH  PE_TTM_000934_SH  \
# count        323.000000        323.000000             323.0             323.0
# mean           0.012384          0.108359               0.0               0.0
# std            0.063142          0.156377               0.0               0.0
# min            0.000000          0.000000               0.0               0.0
# 25%            0.000000          0.000000               0.0               0.0
# 50%            0.000000          0.000000               0.0               0.0
# 75%            0.000000          0.333333               0.0               0.0
# max            0.333333          0.333333               0.0               0.0
#
#        PE_TTM_000935_SH  PE_TTM_399937_SZ  PE_TTM_HSI_HI  PE_TTM_HSCEI_HI
# count             323.0        323.000000          323.0       323.000000
# mean                0.0          0.294118            0.0         0.066047
# std                 0.0          0.107563            0.0         0.133073
# min                 0.0          0.000000            0.0         0.000000
# 25%                 0.0          0.333333            0.0         0.000000
# 50%                 0.0          0.333333            0.0         0.000000
# 75%                 0.0          0.333333            0.0         0.000000
# max                 0.0          0.333333            0.0         0.333333
#
# [8 rows x 34 columns]

# %% [markdown]
# ## 获取收盘数据

# %% [markdown]
# ### 修改指数代码

# %%
#%% 获取收盘数据
from data_reader import get_index_day, get_HKindex_min
start_date = str(pe.index[0])[:10]
end_date = str(pe.index[-1])[:10]

close = dict();symbols=[]
for index in indexes:
    symbol = index[index.find("TTM_")+4:]
    symbol = symbol.replace('_','.')
    if symbol in ['WDQA','884153.WI']:
        temp = pd.read_excel(r"E:\RH\指数行情序列.xlsx", dtype={'date':'datetime64'})
        temp.set_index('date', inplace=True)
        temp = temp[symbol].resample('1W').first()
        close[index] = temp
        symbols.append(symbol)
        print(symbol, 'success!')
        continue
    elif symbol == 'SZ50':
        symbol = '000016.SH'
    elif symbol == 'SH':
        symbol = '000001.SH'
    elif symbol == 'ZZ500':
        symbol = '000905.SH'
    elif symbol == 'CYB':
        symbol = '399006.SZ'
    elif symbol == "HS300":
        symbol = '399300.sz'
    elif symbol in ['HSI.HI','HSCEI.HI']:
        symbol = symbol.split('.')[0]
        temp = get_HKindex_min(symbol, start_date, end_date, freq = '1W')
        close[index] = temp.sclose
        symbols.append(symbol)
        continue
    try:
        temp = get_index_day(symbol, start_date, end_date, freq = '1W')
        close[index] = temp.sclose
        print(symbol, 'success!')
    except:
        print(symbol, "failed")
    symbols.append(symbol)
close = pd.DataFrame(close,index=pe.index)
# Out:
# WDQA success!
# 000016.SH success!
# 000001.SH success!
# 000905.SH success!
# 399006.SZ success!
# 399300.sz success!
# 000925.SH success!
# 399001.SZ success!
# 399985.SZ success!
# 399005.SZ success!
# 000010.SH success!
# 000009.SH success!
# 000922.SH success!
# 399396.SZ success!
# 000991.SH success!
# 000978.SH success!
# 000827.SH success!
# 000998.SH success!
# 399550.SZ success!
# 399971.SZ success!
# 000964.SH success!
# 399812.SZ success!
# 000069.SH success!
# 000065.SH success!
# 884153.WI success!
# 000993.SH success!
# 000931.SH success!
# 000932.SH success!
# 000933.SH success!
# 000934.SH success!
# 000935.SH success!
# 399937.SZ success!

# %%
close = pd.DataFrame(close,index=pe.index)

# %%
close = close[1:]
pos = pos[1:]

# %%
(close/close.iloc[0]).plot(figsize=(15,9))

# %% [markdown]
# ## 回测

# %%
#计算收益
profit, cum_profit, profit_l = pe, pe, pe
for i in range(len(indexes)):
    profit[indexes[i]] = (close[symbols[i]].shift(-1)/close[symbols[i]] - 1) * pos[indexes[i]]

cum_profit['single'] = 1 + (profit.T.sum()).cumsum() 
cum_profit['compound'] = (profit.T.sum()+1).cumprod() 
'''
#计算收益 3周调仓1次
for index in indexes:
    profit_l[indexes[i]] = (close[symbols[i]].shift(-1)/close[symbols[i]] - 1) * longer_pos[indexes[i]]

cum_profit['single_longer'] = 1 + (profit_l.T.sum()).cumsum() 
cum_profit['compound_longer'] = (profit_l.T.sum()+1).cumprod() '''
# Out:
# "\n#计算收益 3周调仓1次\nfor index in indexes:\n    profit_l[indexes[i]] = (close[symbols[i]].shift(-1)/close[symbols[i]] - 1) * longer_pos[indexes[i]]\n\ncum_profit['single_longer'] = 1 + (profit_l.T.sum()).cumsum() \ncum_profit['compound_longer'] = (profit_l.T.sum()+1).cumprod() "

# %%
cum_profit['single'].plot(c='gold',alpha=0.9,figsize=(16,12),linewidth=3)
#cum_profit['compound'].plot(c='orange',alpha=0.9,linewidth=3)
#cum_profit['single_longer'].plot(c='red',alpha=0.9,linewidth=3)
#cum_profit['compound_longer'].plot(c='brown',alpha=0.9,linewidth=3)

#relative_index = pd.DataFrame((close[index]/close[index][0]) for index in symbols).T

#for index in symbols:
#    plt.plot(relative_index[index],alpha=0.7,label=index)
    
#plt.xlim((2008,2019))
#plt.xticks(np.arange(2008,2019))
plt.legend()
#plt.savefig('E:\RH\performance.png',dpi=144)
